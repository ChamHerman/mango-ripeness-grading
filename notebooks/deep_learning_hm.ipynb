# %% [markdown]
# # 🧠 Deep Learning Classifier
# ### Developer: Herman
#
# This notebook covers the training, validation, and serialization of the convolutional neural network model used to grade mango ripeness.

# %%
import torch
import torch.nn as nn
import torchvision

# Model definition, training loop and model.pth exporter...
