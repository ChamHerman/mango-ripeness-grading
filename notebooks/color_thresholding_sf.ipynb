# %% [markdown]
# # 🎨 Color Thresholding & Space Analysis
# ### Developer: Siew Feng
#
# This notebook demonstrates exploratory work on analyzing mango ripeness using HSV and LAB color spaces.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read image
# img = cv2.imread('../data/unripe/mango_1.jpg')
# hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
